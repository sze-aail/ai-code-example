# %% [markdown]
# # 01_confusion_matrix_prf1 notebook
# **Tema:** Confusion matrix + P/R/F1
# Ez a notebook a script-verziot futtatja, igy a tantermi kod es a notebook nem csuszik szet.

# %%
from pathlib import Path
import runpy
# A notebook inline modban mutatja a matplotlib figurakat.
try:
    get_ipython().run_line_magic("matplotlib", "inline")
except Exception:
    pass

# %%
script_path = Path("01_confusion_matrix_prf1.py")
assert script_path.exists(), f"Missing script: {script_path}"
runpy.run_path(str(script_path), run_name="__main__")
